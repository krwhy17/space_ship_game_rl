# %%
import pygame
import os
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import numpy as np
from PIL import Image
import random
import matplotlib.pyplot as plt
from matplotlib import animation
from collections import deque
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.21)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
print(torch.cuda.is_available())  # 應該為 True
print(torch.version.cuda)         # 應該列出 CUDA 版本
print(torch.backends.cudnn.version())  # cuDNN 版本
# Out:
# True
# 12.1
# 90100

# %%
script_dir = os.path.join(os.getcwd(), 'space_ship_game_RL')
if script_dir not in sys.path:
    sys.path.append(script_dir)

from setting import *
from game import Game

# %%
class SpaceShipEnv():
    def __init__(self):
        pygame.init()
        pygame.font.init()

        # 延後畫面初始化，等 render() 時才設置
        self.screen = None
        self.clock = pygame.time.Clock()
        self.fps = FPS

        self.game = Game()

        self.action_space = [0, 1, 2, 3]
        self.observation = self.game.state
        
        # 獎勵機制變數
        self.last_score = 0
        self.last_health = 100
        self.score_milestones = set()
        
        # 射擊相關追蹤變數
        self.last_bullet_count = 0
        self.last_enemy_count = 0
        self.consecutive_no_shoot = 0

    def step(self, action):
        # 記錄動作前的狀態
        prev_enemy_count = len(self.game.enemies) if hasattr(self.game, 'enemies') else 0

        self.game.update(action)

        if self.screen is None:
            self.game.draw()
        else:
            self.game.draw(self.screen)
            self.clock.tick(self.fps)

        # define the state by your game logic
        state = self.game.state

        # 使用 train02.ipynb 的獎勵算法
        reward = 0
        
        # 1. 基礎分數獎勵（主要獎勵來源）
        score_gain = self.game.score - self.last_score
        reward += score_gain * 2.0  # 降低分數獎勵權重
        self.last_score = self.game.score
        
        # 2. 血量變化懲罰
        current_health = self.game.player.sprite.health
        health_change = current_health - self.last_health
        if health_change < 0:
            health_ratio = current_health / 100.0
            base_penalty = abs(health_change) * 10.0
            # 血量越低懲罰越重（非線性增長)
            if health_ratio < 0.5:  # 血量低於50%時額外懲罰
                multiplier = 2.0 - health_ratio  # 0.5血量時multiplier=1.5, 0.1血量時=1.9
                reward -= base_penalty * multiplier
            else:
                reward -= base_penalty
                
        self.last_health = current_health
        
        # 3. 死亡懲罰
        if current_health <= 0:
            reward -= 200  # 提高死亡懲罰
            
        # 4. 簡化里程碑獎勵
        milestones = [100, 500, 1000, 2000, 5000, 10000]  # 大幅減少里程碑
        for milestone in milestones:
            if (self.game.score >= milestone and 
                milestone not in self.score_milestones):
                reward += 20  # 固定里程碑獎勵
                self.score_milestones.add(milestone)
                
        # 5. 射擊獎勵機制（簡化）
        current_bullet_count = len(self.game.player.sprite.bullets) if hasattr(self.game.player.sprite, 'bullets') else 0
        current_enemy_count = len(self.game.enemies) if hasattr(self.game, 'enemies') else 0

        # 檢測擊中敵人（主要射擊獎勵）
        if current_enemy_count < prev_enemy_count and score_gain > 0:
            enemy_killed = prev_enemy_count - current_enemy_count
            reward += enemy_killed * 20.0  # 提高擊殺獎勵
            
        # 6. 提高存活獎勵，並根據血量調整
        if current_health > 0:
            # 基礎存活獎勵
            base_survival_reward = 0.5  # 從 0.1 提高到 0.5
            # 血量越高，存活獎勵越高（鼓勵保持健康）
            health_bonus = (current_health / 100.0) * 0.3
            reward += base_survival_reward + health_bonus
            # 高分時的額外存活獎勵（鼓勵長期存活）
            if self.game.score > 1000:
                reward += 0.2 * (self.game.score / 1000.0)
            
        # 7. 勝利大獎
        if self.game.score >= 10000:
            reward += 1000  # 降低勝利獎勵
         
        done = not self.game.running or self.game.score >= 10000
        info = self.game.score

        return state, reward, done, info

    def reset(self):
        self.game = Game()
        # ✅ 完整重置所有變數
        self.last_score = 0
        self.last_health = 100
        self.score_milestones.clear()
        self.last_bullet_count = 0
        self.last_enemy_count = 0
        self.consecutive_no_shoot = 0

        return self.game.state

    def render(self):
        if self.screen is None:
            self.screen = pygame.display.set_mode((WIDTH, HEIGHT))
            pygame.display.set_caption("SpaceShip RL Environment")

    def close(self):
        pygame.quit()

# %%
# Hyperparameters
num_episodes = 4000
batch_size = 64
gamma = 0.99
lr = 1e-4
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.999
memory_capacity = 60000  # 100000
target_update_freq = 2000   # 1000

# %%
epsilon_list=[]
epsilon=epsilon_start
for i in range(num_episodes):
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    epsilon_list.append(epsilon)
plt.plot(epsilon_list)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# CNN-based DQN Model
class DQN(nn.Module):
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
# Replay buffer
# 用於儲存代理人經驗（狀態、動作、獎勵等）的緩衝區，支援隨機抽樣以打破時間相關性，有助於穩定訓練。

class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
        # Use deque with a fixed capacity to automatically discard the oldest experience when full.
        # 使用 deque 並設定最大長度，當容量滿時會自動移除最舊的資料。

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
        # Store a single transition (experience) in the buffer.
        # 儲存一筆經驗（狀態轉移）進緩衝區。

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        # Randomly sample a batch of transitions to break correlation between consecutive samples.
        # 隨機抽取一批經驗，打破樣本間的時間關聯性，提高訓練穩定性。

        # Unpack each element into separate tensors for network input
        # 將 batch 拆解成分別的 tensor 以供神經網路訓練
        states, actions, rewards, next_states, dones = zip(*batch)
        
        # Convert the sampled data into tensors and move them to the specified device (CPU or GPU)
        # 將抽樣資料轉成 tensor 並移至指定設備（CPU/GPU）
        states = torch.tensor(np.stack(states), dtype=torch.float32, device=device)
        actions = torch.tensor(actions, dtype=torch.int64, device=device)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        next_states = torch.tensor(np.stack(next_states), dtype=torch.float32, device=device)
        dones = torch.tensor(dones, dtype=torch.float32, device=device)
        
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)
        # Return the current size of the buffer.
        # 回傳緩衝區目前儲存的資料數量。

# %%
# Preprocess frames (grayscale and resize to 84x84)
# 預處理影格：轉為灰階並縮放為 84x84

def preprocess_frame(frame):
    # frame 是 numpy array (H, W, 3)，先轉為 PIL Image
    # Input is a color image (RGB), convert to PIL format for easier processing.
    # 輸入是彩色圖像（RGB），轉成 PIL Image 以方便處理。
    image = Image.fromarray(frame)

    # 轉灰階
    # Convert the image to grayscale to reduce input complexity.
    # 將影像轉為灰階，降低輸入維度與計算量。
    image = image.convert('L')

    # resize 成 84x84
    # Resize the image to a standard 84x84 shape, as per DQN convention.
    # 依照 DQN 的慣例將影像統一縮放至 84x84。
    image = image.resize((84, 84), Image.Resampling.BILINEAR)  # or NEAREST, or LANCZOS

    # 轉回 numpy 並正規化
    # Convert back to NumPy and normalize pixel values to [0, 1].
    # 轉回 NumPy 格式並將像素值標準化到 [0, 1]。
    frame = np.asarray(image, dtype=np.float32) / 255.0

    return frame


def stack_frames(stacked_frames, state, is_new_episode):
    # 預處理目前影格
    frame = preprocess_frame(state)

    if is_new_episode or stacked_frames is None:
        # If it's a new episode or no previous frames, initialize with 4 identical frames
        # 若是新的一集或是尚未初始化，則用目前影格複製 4 次形成初始堆疊
        stacked_frames = deque([frame]*4, maxlen=4)
    else:
        # 否則把新影格加入到堆疊中，自動捨棄最舊的
        stacked_frames.append(frame)

    # Stack the 4 frames along the first dimension: shape becomes (4, 84, 84)
    # 沿著第一維（channel）堆疊成 4 通道輸入：形狀變成 (4, 84, 84)
    stacked_state = np.stack(stacked_frames, axis=0)

    return stacked_state, stacked_frames

# %%
# 初始化 Breakout 環境 / Initialize the Breakout environment
env = SpaceShipEnv()
num_actions = len(env.action_space)

# 建立策略網路與目標網路 / Create policy and target networks
policy_net = DQN(num_actions).to(device)
target_net = DQN(num_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())  # 初始時讓目標網路等於策略網路
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=lr)
memory = ReplayMemory(memory_capacity)

# 載入模型（若有）
if os.path.exists('checkpoint.pth'):
    checkpoint = torch.load('checkpoint.pth', map_location=device)
    policy_net.load_state_dict(checkpoint['policy_net'])
    target_net.load_state_dict(checkpoint['target_net'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_episode = checkpoint['episode'] + 1
    total_steps = checkpoint['total_steps']
    best_score = checkpoint['best_score']
    epsilon = checkpoint['epsilon']
    reward_history = checkpoint['reward_history']
    score_history = checkpoint['score_history']
    print(f"Loaded checkpoint from episode {start_episode}, best score: {best_score:.2f}, epsilon={epsilon:.3f}")
else:
    start_episode = 0
    total_steps = 0
    best_score = float('-inf')
    epsilon = epsilon_start
    reward_history = []
    score_history = []


# 訓練迴圈 / Training loop
# 每次可以訓練個100步(根據自己的設備與時間調整)，然後下一次都再接續上次的訓練模型接續往下訓練
# You can train for 100 steps each time (adjust according to your own equipment and time), 
# and then continue training from the last training model next time.
for episode in range(start_episode, 4000): # last time = 3200
    state = env.reset()
    state, stacked_frames = stack_frames(None, state, True)
    total_reward, done = 0, False

    while not done:
        # ε-greedy 策略：隨機選擇動作或從模型中選擇 / Epsilon-greedy action selection
        if random.random() < epsilon:
            action = random.choice(env.action_space)
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
                action = policy_net(state_tensor).argmax(dim=1).item()

        # 執行動作 / Perform action
        next_state, reward, done_, score = env.step(action)
        done = done_
        total_reward += reward

        next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
        memory.push(state, action, reward, next_state, done)
        state = next_state

        # 訓練模型 / Train the model from memory
        if len(memory) >= batch_size:
            states, actions, rewards, next_states, dones = memory.sample(batch_size)

            with torch.no_grad():
                target_q = rewards + gamma * target_net(next_states).max(1)[0] * (1 - dones)

            current_q = policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
            loss = F.mse_loss(current_q, target_q)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # 更新 target 網路 / Periodically update target net
        total_steps += 1
        if total_steps % target_update_freq == 0:
            target_net.load_state_dict(policy_net.state_dict())

    # 更新 epsilon 並紀錄統計資料 / Decay epsilon and log results
    epsilon = max(epsilon_end, epsilon * epsilon_decay)
    reward_history.append(total_reward)
    score_history.append(score)

    print(f"Episode {episode + 1:3d}, Reward: {total_reward:7.2f}, Score: {score:4d}, Epsilon: {epsilon:5.3f}")

    # 儲存模型（若比目前最佳分數更好，或每 50 回合）
    if (episode + 1) % 50 == 0 or score > best_score:
        best_score = max(best_score, score)

        torch.save({
            'policy_net': policy_net.state_dict(),
            'target_net': target_net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epsilon': epsilon,
            'episode': episode,
            'total_steps': total_steps,
            'best_score': best_score,
            'reward_history': reward_history,
            'score_history': score_history,
        }, 'checkpoint.pth')

        print(f"Checkpoint saved at episode {episode + 1}, best score: {best_score:.2f}")

env.close()
# Out:
# Episode   1, Reward: -911.20, Score:  164, Epsilon: 0.999
# Checkpoint saved at episode 1, best score: 164.00
# Episode   2, Reward: -1200.28, Score:  240, Epsilon: 0.998
# Checkpoint saved at episode 2, best score: 240.00
# Episode   3, Reward: -644.87, Score:  400, Epsilon: 0.997
# Checkpoint saved at episode 3, best score: 400.00
# Episode   4, Reward: -230.48, Score:  414, Epsilon: 0.996
# Checkpoint saved at episode 4, best score: 414.00
# Episode   5, Reward: -1266.35, Score:  170, Epsilon: 0.995
# Episode   6, Reward: -715.94, Score:  344, Epsilon: 0.994
# Episode   7, Reward: -1133.74, Score:  290, Epsilon: 0.993
# Episode   8, Reward: -180.25, Score:  478, Epsilon: 0.992
# Checkpoint saved at episode 8, best score: 478.00
# Episode   9, Reward: -985.75, Score:  284, Epsilon: 0.991
# Episode  10, Reward: -243.12, Score:  504, Epsilon: 0.990
# Checkpoint saved at episode 10, best score: 504.00
# Episode  11, Reward: -915.57, Score:  422, Epsilon: 0.989
# Episode  12, Reward: -418.19, Score:  364, Epsilon: 0.988
# Episode  13, Reward:  -35.93, Score:  554, Epsilon: 0.987
# Checkpoint saved at episode 13, best score: 554.00
# Episode  14, Reward:   -3.58, Score:  704, Epsilon: 0.986
# Checkpoint saved at episode 14, best score: 704.00
# Episode  15, Reward: -933.03, Score:  266, Epsilon: 0.985
# Episode  16, Reward: -532.65, Score:  364, Epsilon: 0.984
# Episode  17, Reward: -1366.06, Score:  270, Epsilon: 0.983
# Episode  18, Reward: -728.65, Score:  404, Epsilon: 0.982
# Episode  19, Reward: -1399.65, Score:  172, Epsilon: 0.981
# Episode  20, Reward: -895.66, Score:  384, Epsilon: 0.980
# Episode  21, Reward: -1203.90, Score:  402, Epsilon: 0.979
# Episode  22, Reward: -477.91, Score:  430, Epsilon: 0.978
# Episode  23, Reward: -329.60, Score:  382, Epsilon: 0.977
# Episode  24, Reward: -1286.58, Score:  240, Epsilon: 0.976
# Episode  25, Reward: -966.26, Score:  218, Epsilon: 0.975
# Episode  26, Reward: -906.18, Score:  304, Epsilon: 0.974
# Episode  27, Reward: -843.81, Score:  266, Epsilon: 0.973
# Episode  28, Reward: -341.73, Score:  456, Epsilon: 0.972
# Episode  29, Reward: -1066.52, Score:  132, Epsilon: 0.971
# Episode  30, Reward: -963.92, Score:  214, Epsilon: 0.970
# Episode  31, Reward: -1045.76, Score:  200, Epsilon: 0.969
# Episode  32, Reward: -1233.97, Score:  250, Epsilon: 0.968
# Episode  33, Reward:   -8.84, Score:  640, Epsilon: 0.968
# Episode  34, Reward:   50.44, Score:  422, Epsilon: 0.967
# Episode  35, Reward:  384.45, Score:  676, Epsilon: 0.966
# Episode  36, Reward: -611.39, Score:  320, Epsilon: 0.965
# Episode  37, Reward:  489.77, Score:  870, Epsilon: 0.964
# Checkpoint saved at episode 37, best score: 870.00
# Episode  38, Reward: -700.95, Score:  656, Epsilon: 0.963
# Episode  39, Reward: -432.53, Score:  608, Epsilon: 0.962
# Episode  40, Reward: -767.47, Score:  372, Epsilon: 0.961
# Episode  41, Reward: -471.09, Score:  434, Epsilon: 0.960
# Episode  42, Reward: -1062.16, Score:  290, Epsilon: 0.959
# Episode  43, Reward:  116.54, Score:  634, Epsilon: 0.958
# Episode  44, Reward: -606.41, Score:  356, Epsilon: 0.957
# Episode  45, Reward: -1407.49, Score:  186, Epsilon: 0.956
# Episode  46, Reward: -827.97, Score:  266, Epsilon: 0.955
# Episode  47, Reward:  222.23, Score:  658, Epsilon: 0.954
# Episode  48, Reward:  -57.28, Score:  862, Epsilon: 0.953
# Episode  49, Reward: -666.29, Score:  280, Epsilon: 0.952
# Episode  50, Reward: -1040.00, Score:  202, Epsilon: 0.951
# Checkpoint saved at episode 50, best score: 870.00
# Episode  51, Reward: -280.46, Score:  466, Epsilon: 0.950
# Episode  52, Reward: -574.17, Score:  370, Epsilon: 0.949
# Episode  53, Reward: -625.15, Score:  294, Epsilon: 0.948
# Episode  54, Reward: -559.43, Score:  260, Epsilon: 0.947
# Episode  55, Reward: -188.95, Score:  468, Epsilon: 0.946
# Episode  56, Reward: -1116.76, Score:  334, Epsilon: 0.946
# Episode  57, Reward:  253.69, Score:  826, Epsilon: 0.945
# Episode  58, Reward: -1037.74, Score:  366, Epsilon: 0.944
# Episode  59, Reward: -497.87, Score:  392, Epsilon: 0.943
# Episode  60, Reward: -173.56, Score:  620, Epsilon: 0.942
# Episode  61, Reward: -871.24, Score:  370, Epsilon: 0.941
# Episode  62, Reward: -1417.49, Score:  288, Epsilon: 0.940
# Episode  63, Reward: -1564.59, Score:  338, Epsilon: 0.939
# Episode  64, Reward: -650.52, Score:  338, Epsilon: 0.938
# Episode  65, Reward:  109.59, Score:  710, Epsilon: 0.937
# Episode  66, Reward: -1035.91, Score:  360, Epsilon: 0.936
# Episode  67, Reward: -588.71, Score:  382, Epsilon: 0.935
# Episode  68, Reward: -453.43, Score:  328, Epsilon: 0.934
# Episode  69, Reward:  268.00, Score:  932, Epsilon: 0.933
# Checkpoint saved at episode 69, best score: 932.00
# Episode  70, Reward: -1344.58, Score:  442, Epsilon: 0.932
# Episode  71, Reward: -1551.93, Score:   76, Epsilon: 0.931
# Episode  72, Reward: -1717.44, Score:  152, Epsilon: 0.930
# Episode  73, Reward: -778.82, Score:  308, Epsilon: 0.930
# Episode  74, Reward: -165.33, Score:  522, Epsilon: 0.929
# Episode  75, Reward: -585.54, Score:  402, Epsilon: 0.928
# Episode  76, Reward: -337.91, Score:  370, Epsilon: 0.927
# Episode  77, Reward: -1015.75, Score:  266, Epsilon: 0.926
# Episode  78, Reward: -679.44, Score:  374, Epsilon: 0.925
# Episode  79, Reward:  390.37, Score:  766, Epsilon: 0.924
# Episode  80, Reward: -583.76, Score:  400, Epsilon: 0.923
# Episode  81, Reward:  422.08, Score:  670, Epsilon: 0.922
# Episode  82, Reward: -955.16, Score:  262, Epsilon: 0.921
# Episode  83, Reward:   86.90, Score:  492, Epsilon: 0.920
# Episode  84, Reward: -1328.28, Score:  272, Epsilon: 0.919
# Episode  85, Reward: -462.03, Score:  630, Epsilon: 0.918
# Episode  86, Reward: -1090.74, Score:  196, Epsilon: 0.918
# Episode  87, Reward: -555.65, Score:  392, Epsilon: 0.917
# Episode  88, Reward: -516.93, Score:  344, Epsilon: 0.916
# Episode  89, Reward: -1157.44, Score:  216, Epsilon: 0.915
# Episode  90, Reward: -879.34, Score:  346, Epsilon: 0.914
# Episode  91, Reward: -656.26, Score:  362, Epsilon: 0.913
# Episode  92, Reward: -998.02, Score:  300, Epsilon: 0.912
# Episode  93, Reward:  -38.41, Score:  794, Epsilon: 0.911
# Episode  94, Reward: -160.01, Score:  512, Epsilon: 0.910
# Episode  95, Reward:  -20.07, Score:  582, Epsilon: 0.909
# Episode  96, Reward: -1005.70, Score:  224, Epsilon: 0.908
# Episode  97, Reward: -936.62, Score:  594, Epsilon: 0.908
# Episode  98, Reward: -839.43, Score:  254, Epsilon: 0.907
# Episode  99, Reward: -298.82, Score:  412, Epsilon: 0.906
# Episode 100, Reward: -1503.37, Score:  106, Epsilon: 0.905
# Checkpoint saved at episode 100, best score: 932.00
# Episode 101, Reward: -628.87, Score:  458, Epsilon: 0.904
# Episode 102, Reward: -566.18, Score:  352, Epsilon: 0.903
# Episode 103, Reward: -1189.05, Score:  218, Epsilon: 0.902
# Episode 104, Reward: -684.52, Score:  364, Epsilon: 0.901
# Episode 105, Reward:  237.08, Score:  606, Epsilon: 0.900
# Episode 106, Reward: -1010.72, Score:  212, Epsilon: 0.899
# Episode 107, Reward: -431.55, Score:  388, Epsilon: 0.898
# Episode 108, Reward: -1152.75, Score:  114, Epsilon: 0.898
# Episode 109, Reward: -240.02, Score:  510, Epsilon: 0.897
# Episode 110, Reward: -1031.51, Score:  304, Epsilon: 0.896
# Episode 111, Reward: -1012.53, Score:  316, Epsilon: 0.895
# Episode 112, Reward: -1384.38, Score:  230, Epsilon: 0.894
# Episode 113, Reward: -721.77, Score:  310, Epsilon: 0.893
# Episode 114, Reward:  493.41, Score:  810, Epsilon: 0.892
# Episode 115, Reward: -514.10, Score:  360, Epsilon: 0.891
# Episode 116, Reward: -827.64, Score:  212, Epsilon: 0.890
# Episode 117, Reward: -305.54, Score:  346, Epsilon: 0.890
# Episode 118, Reward: -895.99, Score:  322, Epsilon: 0.889
# Episode 119, Reward:  277.98, Score:  636, Epsilon: 0.888
# Episode 120, Reward: -781.96, Score:  286, Epsilon: 0.887
# Episode 121, Reward: -1170.10, Score:  188, Epsilon: 0.886
# Episode 122, Reward: -1105.91, Score:  216, Epsilon: 0.885
# Episode 123, Reward:   34.77, Score:  668, Epsilon: 0.884
# Episode 124, Reward: -395.94, Score:  474, Epsilon: 0.883
# Episode 125, Reward: 1330.38, Score:  958, Epsilon: 0.882
# Checkpoint saved at episode 125, best score: 958.00
# Episode 126, Reward: -505.77, Score:  478, Epsilon: 0.882
# Episode 127, Reward: -675.85, Score:  308, Epsilon: 0.881
# Episode 128, Reward: -898.32, Score:  204, Epsilon: 0.880
# Episode 129, Reward:   16.98, Score:  538, Epsilon: 0.879
# Episode 130, Reward: -829.37, Score:  246, Epsilon: 0.878
# Episode 131, Reward: -845.20, Score:  282, Epsilon: 0.877
# Episode 132, Reward: -224.77, Score:  516, Epsilon: 0.876
# Episode 133, Reward: -790.77, Score:  320, Epsilon: 0.875
# Episode 134, Reward: -667.64, Score:  284, Epsilon: 0.875
# Episode 135, Reward: -214.89, Score:  414, Epsilon: 0.874
# Episode 136, Reward: -1016.60, Score:  226, Epsilon: 0.873
# Episode 137, Reward: -334.32, Score:  382, Epsilon: 0.872
# Episode 138, Reward: -1330.82, Score:  144, Epsilon: 0.871
# Episode 139, Reward: -717.43, Score:  266, Epsilon: 0.870
# Episode 140, Reward:   26.96, Score:  646, Epsilon: 0.869
# Episode 141, Reward: -1338.47, Score:  320, Epsilon: 0.868
# Episode 142, Reward: -1097.20, Score:  246, Epsilon: 0.868
# Episode 143, Reward: -662.45, Score:  236, Epsilon: 0.867
# Episode 144, Reward: -539.91, Score:  334, Epsilon: 0.866
# Episode 145, Reward: -1049.69, Score:  414, Epsilon: 0.865
# Episode 146, Reward: -983.91, Score:  410, Epsilon: 0.864
# Episode 147, Reward: -731.03, Score:  318, Epsilon: 0.863
# Episode 148, Reward: -1220.50, Score:  278, Epsilon: 0.862
# Episode 149, Reward:  760.45, Score:  856, Epsilon: 0.862
# Episode 150, Reward:  422.08, Score:  662, Epsilon: 0.861
# Checkpoint saved at episode 150, best score: 958.00
# Episode 151, Reward: -767.06, Score:  302, Epsilon: 0.860
# Episode 152, Reward: -346.28, Score:  350, Epsilon: 0.859
# Episode 153, Reward: -558.05, Score:  334, Epsilon: 0.858
# Episode 154, Reward: -605.43, Score:  356, Epsilon: 0.857
# Episode 155, Reward: -1232.40, Score:  216, Epsilon: 0.856
# Episode 156, Reward: -831.28, Score:  372, Epsilon: 0.855
# Episode 157, Reward: -124.23, Score:  664, Epsilon: 0.855
# Episode 158, Reward: -577.75, Score:  418, Epsilon: 0.854
# Episode 159, Reward: -298.48, Score:  490, Epsilon: 0.853
# Episode 160, Reward:  762.48, Score:  730, Epsilon: 0.852
# Episode 161, Reward:   68.17, Score:  666, Epsilon: 0.851
# Episode 162, Reward: -878.21, Score:  304, Epsilon: 0.850
# Episode 163, Reward:  478.58, Score:  556, Epsilon: 0.850
# Episode 164, Reward: -455.69, Score:  352, Epsilon: 0.849
# Episode 165, Reward: -1106.62, Score:  220, Epsilon: 0.848
# Episode 166, Reward: -684.30, Score:  442, Epsilon: 0.847
# Episode 167, Reward: -336.71, Score:  490, Epsilon: 0.846
# Episode 168, Reward:  805.36, Score:  784, Epsilon: 0.845
# Episode 169, Reward: -745.28, Score:  286, Epsilon: 0.844
# Episode 170, Reward: -269.42, Score:  372, Epsilon: 0.844
# Episode 171, Reward: -899.81, Score:  226, Epsilon: 0.843
# Episode 172, Reward: -637.96, Score:  354, Epsilon: 0.842
# Episode 173, Reward: -1004.10, Score:  334, Epsilon: 0.841
# Episode 174, Reward: -157.14, Score:  514, Epsilon: 0.840
# Episode 175, Reward: -960.29, Score:  186, Epsilon: 0.839
# Episode 176, Reward: -1020.81, Score:  214, Epsilon: 0.839
# Episode 177, Reward: -1274.43, Score:  112, Epsilon: 0.838
# Episode 178, Reward: -1165.72, Score:  176, Epsilon: 0.837
# Episode 179, Reward: -256.74, Score:  424, Epsilon: 0.836
# Episode 180, Reward: -359.93, Score:  420, Epsilon: 0.835
# Episode 181, Reward: -230.24, Score:  686, Epsilon: 0.834
# Episode 182, Reward: -481.73, Score:  282, Epsilon: 0.834
# Episode 183, Reward: -605.04, Score:  378, Epsilon: 0.833
# Episode 184, Reward: -906.51, Score:  422, Epsilon: 0.832
# Episode 185, Reward: -1087.68, Score:  318, Epsilon: 0.831
# Episode 186, Reward: -399.15, Score:  518, Epsilon: 0.830
# Episode 187, Reward: -1416.36, Score:   50, Epsilon: 0.829
# Episode 188, Reward: -1302.00, Score:  176, Epsilon: 0.829
# Episode 189, Reward: -174.57, Score:  328, Epsilon: 0.828
# Episode 190, Reward: -928.54, Score:  204, Epsilon: 0.827
# Episode 191, Reward: -745.85, Score:  208, Epsilon: 0.826
# Episode 192, Reward: -919.44, Score:  250, Epsilon: 0.825
# Episode 193, Reward: -563.61, Score:  490, Epsilon: 0.824
# Episode 194, Reward: -912.39, Score:  244, Epsilon: 0.824
# Episode 195, Reward: -239.87, Score:  480, Epsilon: 0.823
# Episode 196, Reward: -675.41, Score:  372, Epsilon: 0.822
# Episode 197, Reward: -877.31, Score:  280, Epsilon: 0.821
# Episode 198, Reward: -406.79, Score:  378, Epsilon: 0.820
# Episode 199, Reward: -378.78, Score:  438, Epsilon: 0.819
# Episode 200, Reward: -1057.52, Score:  214, Epsilon: 0.819
# Checkpoint saved at episode 200, best score: 958.00
# Episode 201, Reward: -929.69, Score:  378, Epsilon: 0.818
# Episode 202, Reward: -1266.16, Score:  278, Epsilon: 0.817
# Episode 203, Reward:  320.73, Score:  502, Epsilon: 0.816
# Episode 204, Reward: -751.71, Score:  440, Epsilon: 0.815
# Episode 205, Reward: -961.28, Score:  480, Epsilon: 0.815
# Episode 206, Reward: -274.10, Score:  438, Epsilon: 0.814
# Episode 207, Reward: -116.51, Score:  516, Epsilon: 0.813
# Episode 208, Reward:  263.30, Score:  750, Epsilon: 0.812
# Episode 209, Reward:  197.84, Score:  522, Epsilon: 0.811
# Episode 210, Reward: -1016.98, Score:  288, Epsilon: 0.810
# Episode 211, Reward:  195.81, Score:  686, Epsilon: 0.810
# Episode 212, Reward: -548.36, Score:  416, Epsilon: 0.809
# Episode 213, Reward: -233.67, Score:  420, Epsilon: 0.808
# Episode 214, Reward: -602.69, Score:  506, Epsilon: 0.807
# Episode 215, Reward:   75.75, Score:  598, Epsilon: 0.806
# Episode 216, Reward: -120.17, Score:  454, Epsilon: 0.806
# Episode 217, Reward:   83.77, Score:  792, Epsilon: 0.805
# Episode 218, Reward:   46.98, Score:  490, Epsilon: 0.804
# Episode 219, Reward:   75.48, Score:  528, Epsilon: 0.803
# Episode 220, Reward: -856.92, Score:  218, Epsilon: 0.802
# Episode 221, Reward: -1272.50, Score:  234, Epsilon: 0.802
# Episode 222, Reward:  635.14, Score:  824, Epsilon: 0.801
# Episode 223, Reward: -779.32, Score:  280, Epsilon: 0.800
# Episode 224, Reward: -967.00, Score:  194, Epsilon: 0.799
# Episode 225, Reward: -518.97, Score:  314, Epsilon: 0.798
# Episode 226, Reward: -971.08, Score:  260, Epsilon: 0.798
# Episode 227, Reward: -1233.01, Score:  304, Epsilon: 0.797
# Episode 228, Reward: -442.23, Score:  322, Epsilon: 0.796
# Episode 229, Reward: -574.52, Score:  376, Epsilon: 0.795
# Episode 230, Reward:  215.23, Score:  584, Epsilon: 0.794
# Episode 231, Reward: -1057.16, Score:  160, Epsilon: 0.794
# Episode 232, Reward: -1061.78, Score:  248, Epsilon: 0.793
# Episode 233, Reward: -1189.08, Score:  138, Epsilon: 0.792
# Episode 234, Reward: -785.51, Score:  386, Epsilon: 0.791
# Episode 235, Reward: -996.65, Score:  420, Epsilon: 0.790
# Episode 236, Reward: -748.59, Score:  470, Epsilon: 0.790
# Episode 237, Reward: -1133.22, Score:  134, Epsilon: 0.789
# Episode 238, Reward: -817.92, Score:  312, Epsilon: 0.788
# Episode 239, Reward: -1058.74, Score:  182, Epsilon: 0.787
# Episode 240, Reward: -256.42, Score:  482, Epsilon: 0.787
# Episode 241, Reward: -905.69, Score:  234, Epsilon: 0.786
# Episode 242, Reward: -1394.75, Score:  256, Epsilon: 0.785
# Episode 243, Reward: -451.42, Score:  510, Epsilon: 0.784
# Episode 244, Reward: -1309.14, Score:  262, Epsilon: 0.783
# Episode 245, Reward: -408.94, Score:  512, Epsilon: 0.783
# Episode 246, Reward: -974.07, Score:  184, Epsilon: 0.782
# Episode 247, Reward: -498.67, Score:  378, Epsilon: 0.781
# Episode 248, Reward:  -50.00, Score:  476, Epsilon: 0.780
# Episode 249, Reward: -1043.18, Score:  298, Epsilon: 0.779
# Episode 250, Reward: -1017.43, Score:  342, Epsilon: 0.779
# Checkpoint saved at episode 250, best score: 958.00
# Episode 251, Reward: -359.60, Score:  402, Epsilon: 0.778
# Episode 252, Reward: -1261.24, Score:  254, Epsilon: 0.777
# Episode 253, Reward: -1033.18, Score:  488, Epsilon: 0.776
# Episode 254, Reward: -278.23, Score:  574, Epsilon: 0.776
# Episode 255, Reward: -853.52, Score:  404, Epsilon: 0.775
# Episode 256, Reward: -297.88, Score:  564, Epsilon: 0.774
# Episode 257, Reward: -106.25, Score:  602, Epsilon: 0.773
# Episode 258, Reward: -273.40, Score:  376, Epsilon: 0.772
# Episode 259, Reward: -842.53, Score:  198, Epsilon: 0.772
# Episode 260, Reward: -1330.69, Score:  138, Epsilon: 0.771
# Episode 261, Reward: -906.39, Score:  292, Epsilon: 0.770
# Episode 262, Reward: -705.71, Score:  318, Epsilon: 0.769
# Episode 263, Reward: -1610.82, Score:  220, Epsilon: 0.769
# Episode 264, Reward: -428.52, Score:  342, Epsilon: 0.768
# Episode 265, Reward: -293.42, Score:  606, Epsilon: 0.767
# Episode 266, Reward: -798.13, Score:  206, Epsilon: 0.766
# Episode 267, Reward: -452.35, Score:  462, Epsilon: 0.766
# Episode 268, Reward: -1139.21, Score:  162, Epsilon: 0.765
# Episode 269, Reward: -794.02, Score:  258, Epsilon: 0.764
# Episode 270, Reward: -1166.02, Score:  286, Epsilon: 0.763
# Episode 271, Reward: -365.03, Score:  504, Epsilon: 0.763
# Episode 272, Reward: -114.22, Score:  426, Epsilon: 0.762
# Episode 273, Reward:   33.99, Score:  548, Epsilon: 0.761
# Episode 274, Reward: -1466.34, Score:  108, Epsilon: 0.760
# Episode 275, Reward: -167.72, Score:  690, Epsilon: 0.759
# Episode 276, Reward: -1033.91, Score:  268, Epsilon: 0.759
# Episode 277, Reward: -453.09, Score:  298, Epsilon: 0.758
# Episode 278, Reward: -966.11, Score:  328, Epsilon: 0.757
# Episode 279, Reward:  175.92, Score:  730, Epsilon: 0.756
# Episode 280, Reward: -644.15, Score:  268, Epsilon: 0.756
# Episode 281, Reward:  304.00, Score:  906, Epsilon: 0.755
# Episode 282, Reward: -267.09, Score:  498, Epsilon: 0.754
# Episode 283, Reward: -730.22, Score:  312, Epsilon: 0.753
# Episode 284, Reward: -1163.68, Score:  270, Epsilon: 0.753
# Episode 285, Reward: -841.45, Score:  214, Epsilon: 0.752
# Episode 286, Reward: -678.30, Score:  372, Epsilon: 0.751
# Episode 287, Reward: -1224.52, Score:  184, Epsilon: 0.750
# Episode 288, Reward:  598.23, Score:  700, Epsilon: 0.750
# Episode 289, Reward: -980.10, Score:  182, Epsilon: 0.749
# Episode 290, Reward: -1079.44, Score:  250, Epsilon: 0.748
# Episode 291, Reward: -432.89, Score:  376, Epsilon: 0.747
# Episode 292, Reward: -445.37, Score:  362, Epsilon: 0.747
# Episode 293, Reward:  -53.73, Score:  488, Epsilon: 0.746
# Episode 294, Reward: -411.59, Score:  490, Epsilon: 0.745
# Episode 295, Reward: -351.41, Score:  438, Epsilon: 0.744
# Episode 296, Reward: -1041.69, Score:  186, Epsilon: 0.744
# Episode 297, Reward: -869.83, Score:  286, Epsilon: 0.743
# Episode 298, Reward: -649.91, Score:  274, Epsilon: 0.742
# Episode 299, Reward: -711.98, Score:  286, Epsilon: 0.741
# Episode 300, Reward: -552.73, Score:  526, Epsilon: 0.741
# Checkpoint saved at episode 300, best score: 958.00
# Episode 301, Reward:  -36.39, Score:  592, Epsilon: 0.740
# Episode 302, Reward:  219.31, Score:  564, Epsilon: 0.739
# Episode 303, Reward: -919.86, Score:  254, Epsilon: 0.738
# Episode 304, Reward: -997.89, Score:  192, Epsilon: 0.738
# Episode 305, Reward: -945.22, Score:  274, Epsilon: 0.737
# Episode 306, Reward: -422.50, Score:  304, Epsilon: 0.736
# Episode 307, Reward: -556.66, Score:  230, Epsilon: 0.736
# Episode 308, Reward:  -80.56, Score:  502, Epsilon: 0.735
# Episode 309, Reward: -919.03, Score:  200, Epsilon: 0.734
# Episode 310, Reward: -762.88, Score:  282, Epsilon: 0.733
# Episode 311, Reward:  -19.39, Score:  556, Epsilon: 0.733
# Episode 312, Reward: -685.76, Score:  466, Epsilon: 0.732
# Episode 313, Reward: -872.41, Score:  314, Epsilon: 0.731
# Episode 314, Reward:  291.15, Score:  540, Epsilon: 0.730
# Episode 315, Reward: -1128.23, Score:  296, Epsilon: 0.730
# Episode 316, Reward: -226.04, Score:  448, Epsilon: 0.729
# Episode 317, Reward:   45.04, Score:  484, Epsilon: 0.728
# Episode 318, Reward: -651.58, Score:  286, Epsilon: 0.727
# Episode 319, Reward:   78.24, Score:  752, Epsilon: 0.727
# Episode 320, Reward: -1516.00, Score:  174, Epsilon: 0.726
# Episode 321, Reward: -757.63, Score:  220, Epsilon: 0.725
# Episode 322, Reward: -820.36, Score:  262, Epsilon: 0.725
# Episode 323, Reward: -1184.82, Score:  238, Epsilon: 0.724
# Episode 324, Reward: -1156.30, Score:  130, Epsilon: 0.723
# Episode 325, Reward: -1049.10, Score:  160, Epsilon: 0.722
# Episode 326, Reward: -1186.90, Score:  254, Epsilon: 0.722
# Episode 327, Reward: -586.51, Score:  314, Epsilon: 0.721
# Episode 328, Reward:  478.83, Score:  732, Epsilon: 0.720
# Episode 329, Reward: -644.32, Score:  370, Epsilon: 0.720
# Episode 330, Reward: -1166.38, Score:  164, Epsilon: 0.719
# Episode 331, Reward: -509.77, Score:  570, Epsilon: 0.718
# Episode 332, Reward: -1149.58, Score:  160, Epsilon: 0.717
# Episode 333, Reward: -831.41, Score:  272, Epsilon: 0.717
# Episode 334, Reward: -585.06, Score:  340, Epsilon: 0.716
# Episode 335, Reward: -769.23, Score:  320, Epsilon: 0.715
# Episode 336, Reward: -910.17, Score:  430, Epsilon: 0.715
# Episode 337, Reward: -639.37, Score:  300, Epsilon: 0.714
# Episode 338, Reward: -880.37, Score:  308, Epsilon: 0.713
# Episode 339, Reward: -630.28, Score:  356, Epsilon: 0.712
# Episode 340, Reward: -161.09, Score:  530, Epsilon: 0.712
# Episode 341, Reward: -675.45, Score:  396, Epsilon: 0.711
# Episode 342, Reward: -688.09, Score:  316, Epsilon: 0.710
# Episode 343, Reward: -364.22, Score:  324, Epsilon: 0.710
# Episode 344, Reward: -658.40, Score:  560, Epsilon: 0.709
# Episode 345, Reward:   66.89, Score:  676, Epsilon: 0.708
# Episode 346, Reward: -644.14, Score:  464, Epsilon: 0.707
# Episode 347, Reward: -979.67, Score:  178, Epsilon: 0.707
# Episode 348, Reward: -1355.47, Score:  234, Epsilon: 0.706
# Episode 349, Reward: -921.87, Score:  262, Epsilon: 0.705
# Episode 350, Reward: -1131.99, Score:  270, Epsilon: 0.705
# Checkpoint saved at episode 350, best score: 958.00
# Episode 351, Reward: -243.43, Score:  630, Epsilon: 0.704
# Episode 352, Reward: -696.56, Score:  246, Epsilon: 0.703
# Episode 353, Reward: -1311.91, Score:  136, Epsilon: 0.702
# Episode 354, Reward: -1143.59, Score:  402, Epsilon: 0.702
# Episode 355, Reward:  -95.90, Score:  576, Epsilon: 0.701
# Episode 356, Reward: -709.11, Score:  258, Epsilon: 0.700
# Episode 357, Reward: -635.70, Score:  488, Epsilon: 0.700
# Episode 358, Reward: 2268.64, Score: 1406, Epsilon: 0.699
# Checkpoint saved at episode 358, best score: 1406.00
# Episode 359, Reward: -886.42, Score:  230, Epsilon: 0.698
# Episode 360, Reward: -576.29, Score:  412, Epsilon: 0.698
# Episode 361, Reward:   45.90, Score:  522, Epsilon: 0.697
# Episode 362, Reward: -826.01, Score:  366, Epsilon: 0.696
# Episode 363, Reward: -859.39, Score:  268, Epsilon: 0.695
# Episode 364, Reward: -1242.73, Score:  408, Epsilon: 0.695
# Episode 365, Reward: -970.28, Score:  174, Epsilon: 0.694
# Episode 366, Reward:  223.86, Score:  562, Epsilon: 0.693
# Episode 367, Reward: -1007.82, Score:  272, Epsilon: 0.693
# Episode 368, Reward: 1209.19, Score: 1044, Epsilon: 0.692
# Episode 369, Reward: -723.45, Score:  290, Epsilon: 0.691
# Episode 370, Reward:  246.12, Score:  722, Epsilon: 0.691
# Episode 371, Reward: -774.40, Score:  406, Epsilon: 0.690
# Episode 372, Reward: -842.18, Score:  256, Epsilon: 0.689
# Episode 373, Reward: -415.29, Score:  452, Epsilon: 0.689
# Episode 374, Reward:  482.85, Score:  798, Epsilon: 0.688
# Episode 375, Reward: -692.71, Score:  284, Epsilon: 0.687
# Episode 376, Reward:  754.79, Score:  956, Epsilon: 0.686
# Episode 377, Reward: -611.34, Score:  760, Epsilon: 0.686
# Episode 378, Reward: -182.04, Score:  582, Epsilon: 0.685
# Episode 379, Reward: -943.11, Score:  270, Epsilon: 0.684
# Episode 380, Reward: -543.56, Score:  380, Epsilon: 0.684
# Episode 381, Reward: -427.89, Score:  592, Epsilon: 0.683
# Episode 382, Reward: -1168.41, Score:  142, Epsilon: 0.682
# Episode 383, Reward: -906.05, Score:  222, Epsilon: 0.682
# Episode 384, Reward: -1552.34, Score:  250, Epsilon: 0.681
# Episode 385, Reward: -1293.56, Score:  388, Epsilon: 0.680
# Episode 386, Reward: -1445.88, Score:  370, Epsilon: 0.680
# Episode 387, Reward: -805.82, Score:  276, Epsilon: 0.679
# Episode 388, Reward: -1373.37, Score:  184, Epsilon: 0.678
# Episode 389, Reward: -630.15, Score:  604, Epsilon: 0.678
# Episode 390, Reward: -1293.74, Score:  230, Epsilon: 0.677
# Episode 391, Reward: -1357.66, Score:  328, Epsilon: 0.676
# Episode 392, Reward:  226.58, Score:  564, Epsilon: 0.676
# Episode 393, Reward: -887.32, Score:  392, Epsilon: 0.675
# Episode 394, Reward: -362.09, Score:  494, Epsilon: 0.674
# Episode 395, Reward: -554.25, Score:  502, Epsilon: 0.674
# Episode 396, Reward: -1261.04, Score:  186, Epsilon: 0.673
# Episode 397, Reward: -1552.25, Score:  118, Epsilon: 0.672
# Episode 398, Reward: -348.89, Score:  454, Epsilon: 0.672
# Episode 399, Reward: -647.16, Score:  392, Epsilon: 0.671
# Episode 400, Reward: -1096.35, Score:  246, Epsilon: 0.670
# Checkpoint saved at episode 400, best score: 1406.00
# Episode 401, Reward: -375.74, Score:  490, Epsilon: 0.670
# Episode 402, Reward: -1362.31, Score:  124, Epsilon: 0.669
# Episode 403, Reward:   15.27, Score:  432, Epsilon: 0.668
# Episode 404, Reward: -694.01, Score:  296, Epsilon: 0.668
# Episode 405, Reward: -242.60, Score:  378, Epsilon: 0.667
# Episode 406, Reward: -721.96, Score:  374, Epsilon: 0.666
# Episode 407, Reward: -976.34, Score:  270, Epsilon: 0.666
# Episode 408, Reward: -172.94, Score:  590, Epsilon: 0.665
# Episode 409, Reward: -767.00, Score:  224, Epsilon: 0.664
# Episode 410, Reward: -1005.38, Score:  216, Epsilon: 0.664
# Episode 411, Reward: -1440.48, Score:  314, Epsilon: 0.663
# Episode 412, Reward:  -41.57, Score:  472, Epsilon: 0.662
# Episode 413, Reward: -733.82, Score:  386, Epsilon: 0.662
# Episode 414, Reward: -1218.35, Score:  152, Epsilon: 0.661
# Episode 415, Reward: -240.12, Score:  448, Epsilon: 0.660
# Episode 416, Reward: -316.34, Score:  390, Epsilon: 0.660
# Episode 417, Reward: -674.87, Score:  334, Epsilon: 0.659
# Episode 418, Reward: -808.42, Score:  284, Epsilon: 0.658
# Episode 419, Reward: -127.81, Score:  566, Epsilon: 0.658
# Episode 420, Reward: -841.43, Score:  356, Epsilon: 0.657
# Episode 421, Reward: -450.39, Score:  382, Epsilon: 0.656
# Episode 422, Reward: -1038.62, Score:  116, Epsilon: 0.656
# Episode 423, Reward: -329.59, Score:  484, Epsilon: 0.655
# Episode 424, Reward: -448.54, Score:  424, Epsilon: 0.654
# Episode 425, Reward: -1052.89, Score:  266, Epsilon: 0.654
# Episode 426, Reward: -647.21, Score:  368, Epsilon: 0.653
# Episode 427, Reward:  371.28, Score:  742, Epsilon: 0.652
# Episode 428, Reward: -1217.69, Score:  198, Epsilon: 0.652
# Episode 429, Reward: 2401.22, Score: 1562, Epsilon: 0.651
# Checkpoint saved at episode 429, best score: 1562.00
# Episode 430, Reward: -256.58, Score:  370, Epsilon: 0.650
# Episode 431, Reward: -863.87, Score:  342, Epsilon: 0.650
# Episode 432, Reward: -1107.04, Score:  102, Epsilon: 0.649
# Episode 433, Reward: -190.92, Score:  480, Epsilon: 0.648
# Episode 434, Reward: -390.76, Score:  512, Epsilon: 0.648
# Episode 435, Reward: -235.55, Score:  610, Epsilon: 0.647
# Episode 436, Reward:  359.50, Score: 1090, Epsilon: 0.646
# Episode 437, Reward: -683.73, Score:  394, Epsilon: 0.646
# Episode 438, Reward: -483.51, Score:  574, Epsilon: 0.645
# Episode 439, Reward: -938.62, Score:  294, Epsilon: 0.645
# Episode 440, Reward: -1020.87, Score:  218, Epsilon: 0.644
# Episode 441, Reward: -657.22, Score:  734, Epsilon: 0.643
# Episode 442, Reward: -1041.65, Score:  218, Epsilon: 0.643
# Episode 443, Reward: -1166.12, Score:  496, Epsilon: 0.642
# Episode 444, Reward: -330.32, Score:  330, Epsilon: 0.641
# Episode 445, Reward: 1834.33, Score: 1396, Epsilon: 0.641
# Episode 446, Reward: -1234.93, Score:  300, Epsilon: 0.640
# Episode 447, Reward: -1075.60, Score:  294, Epsilon: 0.639
# Episode 448, Reward: -757.26, Score:  250, Epsilon: 0.639
# Episode 449, Reward: -967.10, Score:  362, Epsilon: 0.638
# Episode 450, Reward:  309.47, Score:  636, Epsilon: 0.637
# Checkpoint saved at episode 450, best score: 1562.00
# Episode 451, Reward: -1185.97, Score:  292, Epsilon: 0.637
# Episode 452, Reward: -660.87, Score:  276, Epsilon: 0.636
# Episode 453, Reward: -728.09, Score:  302, Epsilon: 0.636
# Episode 454, Reward: -295.29, Score:  432, Epsilon: 0.635
# Episode 455, Reward: -449.31, Score:  362, Epsilon: 0.634
# Episode 456, Reward: -756.92, Score:  246, Epsilon: 0.634
# Episode 457, Reward: -755.14, Score:  322, Epsilon: 0.633
# Episode 458, Reward: -421.70, Score:  338, Epsilon: 0.632
# Episode 459, Reward: -583.28, Score:  356, Epsilon: 0.632
# Episode 460, Reward: -967.93, Score:  286, Epsilon: 0.631
# Episode 461, Reward: -1025.32, Score:  138, Epsilon: 0.631
# Episode 462, Reward: -365.43, Score:  510, Epsilon: 0.630
# Episode 463, Reward: -871.69, Score:  468, Epsilon: 0.629
# Episode 464, Reward: -918.48, Score:  252, Epsilon: 0.629
# Episode 465, Reward: -799.86, Score:  464, Epsilon: 0.628
# Episode 466, Reward: -590.63, Score:  462, Epsilon: 0.627
# Episode 467, Reward: -246.78, Score:  742, Epsilon: 0.627
# Episode 468, Reward:  436.18, Score:  856, Epsilon: 0.626
# Episode 469, Reward: -472.10, Score:  406, Epsilon: 0.625
# Episode 470, Reward: -785.98, Score:  340, Epsilon: 0.625
# Episode 471, Reward: -1068.49, Score:  312, Epsilon: 0.624
# Episode 472, Reward: -669.96, Score:  464, Epsilon: 0.624
# Episode 473, Reward:  854.58, Score:  884, Epsilon: 0.623
# Episode 474, Reward: -348.93, Score:  580, Epsilon: 0.622
# Episode 475, Reward: -1058.61, Score:  242, Epsilon: 0.622
# Episode 476, Reward: -682.16, Score:  308, Epsilon: 0.621
# Episode 477, Reward: -904.88, Score:  302, Epsilon: 0.620
# Episode 478, Reward: -1208.41, Score:  220, Epsilon: 0.620
# Episode 479, Reward: -168.53, Score:  582, Epsilon: 0.619
# Episode 480, Reward:   -6.13, Score:  544, Epsilon: 0.619
# Episode 481, Reward: -917.98, Score:  258, Epsilon: 0.618
# Episode 482, Reward: -754.29, Score:  294, Epsilon: 0.617
# Episode 483, Reward: -1071.02, Score:  184, Epsilon: 0.617
# Episode 484, Reward: -890.16, Score:  262, Epsilon: 0.616
# Episode 485, Reward: -890.61, Score:  320, Epsilon: 0.616
# Episode 486, Reward: -1576.99, Score:   68, Epsilon: 0.615
# Episode 487, Reward: -854.08, Score:  392, Epsilon: 0.614
# Episode 488, Reward: -956.01, Score:  272, Epsilon: 0.614
# Episode 489, Reward: -608.05, Score:  314, Epsilon: 0.613
# Episode 490, Reward: -1477.76, Score:   94, Epsilon: 0.612
# Episode 491, Reward: -296.70, Score:  486, Epsilon: 0.612
# Episode 492, Reward: -489.38, Score:  298, Epsilon: 0.611
# Episode 493, Reward: -838.88, Score:  218, Epsilon: 0.611
# Episode 494, Reward:  111.68, Score:  504, Epsilon: 0.610
# Episode 495, Reward: -1080.84, Score:  438, Epsilon: 0.609
# Episode 496, Reward:    9.46, Score:  522, Epsilon: 0.609
# Episode 497, Reward: -1085.81, Score:  262, Epsilon: 0.608
# Episode 498, Reward: -441.17, Score:  378, Epsilon: 0.608
# Episode 499, Reward: -1096.31, Score:  160, Epsilon: 0.607
# Episode 500, Reward: -955.35, Score:  396, Epsilon: 0.606
# Checkpoint saved at episode 500, best score: 1562.00
# Episode 501, Reward: -1488.82, Score:  150, Epsilon: 0.606
# Episode 502, Reward: -1054.98, Score:  392, Epsilon: 0.605
# Episode 503, Reward: -915.35, Score:  224, Epsilon: 0.605
# Episode 504, Reward: -563.64, Score:  472, Epsilon: 0.604
# Episode 505, Reward: -939.23, Score:  218, Epsilon: 0.603
# Episode 506, Reward: -837.50, Score:  320, Epsilon: 0.603
# Episode 507, Reward: -1250.68, Score:  138, Epsilon: 0.602
# Episode 508, Reward: -882.70, Score:  286, Epsilon: 0.602
# Episode 509, Reward: -801.46, Score:  426, Epsilon: 0.601
# Episode 510, Reward: -465.13, Score:  298, Epsilon: 0.600
# Episode 511, Reward: -1024.81, Score:  330, Epsilon: 0.600
# Episode 512, Reward:  431.74, Score:  722, Epsilon: 0.599
# Episode 513, Reward: -888.83, Score:  278, Epsilon: 0.599
# Episode 514, Reward: -721.24, Score:  312, Epsilon: 0.598
# Episode 515, Reward: -982.26, Score:  470, Epsilon: 0.597
# Episode 516, Reward: -1097.93, Score:  344, Epsilon: 0.597
# Episode 517, Reward: 1091.82, Score:  840, Epsilon: 0.596
# Episode 518, Reward: -1228.30, Score:   92, Epsilon: 0.596
# Episode 519, Reward: -188.23, Score:  428, Epsilon: 0.595
# Episode 520, Reward: -492.76, Score:  518, Epsilon: 0.594
# Episode 521, Reward: -1231.27, Score:  126, Epsilon: 0.594
# Episode 522, Reward: -621.86, Score:  458, Epsilon: 0.593
# Episode 523, Reward: -939.11, Score:  234, Epsilon: 0.593
# Episode 524, Reward: -798.89, Score:  278, Epsilon: 0.592
# Episode 525, Reward: -1142.88, Score:  336, Epsilon: 0.591
# Episode 526, Reward: -385.54, Score:  468, Epsilon: 0.591
# Episode 527, Reward:  960.84, Score:  854, Epsilon: 0.590
# Episode 528, Reward: -534.86, Score:  548, Epsilon: 0.590
# Episode 529, Reward:   91.88, Score:  588, Epsilon: 0.589
# Episode 530, Reward: -569.89, Score:  304, Epsilon: 0.588
# Episode 531, Reward: -1784.29, Score:  110, Epsilon: 0.588
# Episode 532, Reward: -1316.74, Score:  280, Epsilon: 0.587
# Episode 533, Reward: -655.00, Score:  282, Epsilon: 0.587
# Episode 534, Reward:  209.63, Score:  550, Epsilon: 0.586
# Episode 535, Reward: -744.82, Score:  462, Epsilon: 0.586
# Episode 536, Reward: -1227.77, Score:  296, Epsilon: 0.585
# Episode 537, Reward: -832.17, Score:  326, Epsilon: 0.584
# Episode 538, Reward: -716.21, Score:  652, Epsilon: 0.584
# Episode 539, Reward: -1017.75, Score:  238, Epsilon: 0.583
# Episode 540, Reward: -643.87, Score:  304, Epsilon: 0.583
# Episode 541, Reward: -719.12, Score:  268, Epsilon: 0.582
# Episode 542, Reward: -774.99, Score:  288, Epsilon: 0.581
# Episode 543, Reward: -746.45, Score:  294, Epsilon: 0.581
# Episode 544, Reward: -1157.76, Score:  140, Epsilon: 0.580
# Episode 545, Reward: 1334.80, Score: 1108, Epsilon: 0.580
# Episode 546, Reward: -337.21, Score:  468, Epsilon: 0.579
# Episode 547, Reward: -629.76, Score:  350, Epsilon: 0.579
# Episode 548, Reward:  931.15, Score:  876, Epsilon: 0.578
# Episode 549, Reward: -887.86, Score:  198, Epsilon: 0.577
# Episode 550, Reward: -755.66, Score:  374, Epsilon: 0.577
# Checkpoint saved at episode 550, best score: 1562.00
# Episode 551, Reward: -636.94, Score:  320, Epsilon: 0.576
# Episode 552, Reward: -1036.30, Score:  270, Epsilon: 0.576
# Episode 553, Reward:  -33.31, Score:  434, Epsilon: 0.575
# Episode 554, Reward: -359.14, Score:  418, Epsilon: 0.574
# Episode 555, Reward: -336.99, Score:  436, Epsilon: 0.574
# Episode 556, Reward: -235.49, Score:  534, Epsilon: 0.573
# Episode 557, Reward: -1122.05, Score:  106, Epsilon: 0.573
# Episode 558, Reward: -318.58, Score:  570, Epsilon: 0.572
# Episode 559, Reward: -1264.24, Score:  144, Epsilon: 0.572
# Episode 560, Reward:  351.09, Score:  672, Epsilon: 0.571
# Episode 561, Reward: -869.38, Score:  374, Epsilon: 0.570
# Episode 562, Reward: -815.56, Score:  362, Epsilon: 0.570
# Episode 563, Reward: -341.77, Score:  568, Epsilon: 0.569
# Episode 564, Reward:  667.47, Score:  866, Epsilon: 0.569
# Episode 565, Reward: -822.02, Score:  270, Epsilon: 0.568
# Episode 566, Reward:  753.11, Score:  984, Epsilon: 0.568
# Episode 567, Reward: -468.54, Score:  402, Epsilon: 0.567
# Episode 568, Reward: -1246.42, Score:  168, Epsilon: 0.566
# Episode 569, Reward:  317.33, Score:  612, Epsilon: 0.566
# Episode 570, Reward: -806.98, Score:  234, Epsilon: 0.565
# Episode 571, Reward: -649.99, Score:  406, Epsilon: 0.565
# Episode 572, Reward:  287.89, Score:  698, Epsilon: 0.564
# Episode 573, Reward:  841.42, Score:  678, Epsilon: 0.564
# Episode 574, Reward:   44.42, Score:  492, Epsilon: 0.563
# Episode 575, Reward: -1059.25, Score:  198, Epsilon: 0.563
# Episode 576, Reward: -1018.89, Score:  210, Epsilon: 0.562
# Episode 577, Reward: -196.26, Score:  388, Epsilon: 0.561
# Episode 578, Reward: -583.17, Score:  452, Epsilon: 0.561
# Episode 579, Reward: -1250.03, Score:  162, Epsilon: 0.560
# Episode 580, Reward: -996.54, Score:  338, Epsilon: 0.560
# Episode 581, Reward: -261.89, Score:  418, Epsilon: 0.559
# Episode 582, Reward: -575.71, Score:  268, Epsilon: 0.559
# Episode 583, Reward: -548.53, Score:  420, Epsilon: 0.558
# Episode 584, Reward: -850.74, Score:  240, Epsilon: 0.558
# Episode 585, Reward:  842.70, Score:  910, Epsilon: 0.557
# Episode 586, Reward: -880.56, Score:  584, Epsilon: 0.556
# Episode 587, Reward: -570.61, Score:  386, Epsilon: 0.556
# Episode 588, Reward: -775.20, Score:  264, Epsilon: 0.555
# Episode 589, Reward: -1202.49, Score:  380, Epsilon: 0.555
# Episode 590, Reward: -740.45, Score:  464, Epsilon: 0.554
# Episode 591, Reward: -928.38, Score:  362, Epsilon: 0.554
# Episode 592, Reward: -1064.59, Score:  202, Epsilon: 0.553
# Episode 593, Reward:  424.67, Score:  630, Epsilon: 0.553
# Episode 594, Reward: -1396.27, Score:   92, Epsilon: 0.552
# Episode 595, Reward: -976.49, Score:  246, Epsilon: 0.551
# Episode 596, Reward:  605.84, Score:  684, Epsilon: 0.551
# Episode 597, Reward:   -6.12, Score:  590, Epsilon: 0.550
# Episode 598, Reward: -203.14, Score:  494, Epsilon: 0.550
# Episode 599, Reward: -1193.48, Score:  140, Epsilon: 0.549
# Episode 600, Reward: -1279.12, Score:  230, Epsilon: 0.549
# Checkpoint saved at episode 600, best score: 1562.00
# Episode 601, Reward: -142.98, Score:  720, Epsilon: 0.548
# Episode 602, Reward: -1087.42, Score:  206, Epsilon: 0.548
# Episode 603, Reward: -562.37, Score:  346, Epsilon: 0.547
# Episode 604, Reward: -538.49, Score:  390, Epsilon: 0.546
# Episode 605, Reward: -234.62, Score:  514, Epsilon: 0.546
# Episode 606, Reward:  114.06, Score:  616, Epsilon: 0.545
# Episode 607, Reward: -1293.60, Score:  152, Epsilon: 0.545
# Episode 608, Reward:  169.41, Score:  630, Epsilon: 0.544
# Episode 609, Reward: -762.32, Score:  462, Epsilon: 0.544
# Episode 610, Reward: -1321.44, Score:  180, Epsilon: 0.543
# Episode 611, Reward: -1054.00, Score:  222, Epsilon: 0.543
# Episode 612, Reward:  -45.14, Score:  808, Epsilon: 0.542
# Episode 613, Reward:  -60.12, Score:  484, Epsilon: 0.542
# Episode 614, Reward: -367.04, Score:  556, Epsilon: 0.541
# Episode 615, Reward:  787.32, Score:  752, Epsilon: 0.540
# Episode 616, Reward: -1289.76, Score:  336, Epsilon: 0.540
# Episode 617, Reward:  544.80, Score:  598, Epsilon: 0.539
# Episode 618, Reward: -1113.09, Score:  264, Epsilon: 0.539
# Episode 619, Reward: -324.31, Score:  398, Epsilon: 0.538
# Episode 620, Reward:  850.68, Score:  972, Epsilon: 0.538
# Episode 621, Reward: -488.91, Score:  344, Epsilon: 0.537
# Episode 622, Reward: -825.17, Score:  302, Epsilon: 0.537
# Episode 623, Reward:  -23.84, Score:  458, Epsilon: 0.536
# Episode 624, Reward: -1284.98, Score:  212, Epsilon: 0.536
# Episode 625, Reward: -1374.10, Score:  144, Epsilon: 0.535
# Episode 626, Reward: -685.62, Score:  390, Epsilon: 0.535
# Episode 627, Reward: -995.29, Score:  276, Epsilon: 0.534
# Episode 628, Reward: -960.06, Score:  280, Epsilon: 0.533
# Episode 629, Reward: -271.39, Score:  420, Epsilon: 0.533
# Episode 630, Reward: -626.02, Score:  518, Epsilon: 0.532
# Episode 631, Reward: -1428.44, Score:  210, Epsilon: 0.532
# Episode 632, Reward: -731.94, Score:  422, Epsilon: 0.531
# Episode 633, Reward: -349.65, Score:  518, Epsilon: 0.531
# Episode 634, Reward: -1139.94, Score:  168, Epsilon: 0.530
# Episode 635, Reward: -698.79, Score:  392, Epsilon: 0.530
# Episode 636, Reward: -364.88, Score:  462, Epsilon: 0.529
# Episode 637, Reward: -885.36, Score:  236, Epsilon: 0.529
# Episode 638, Reward: -602.08, Score:  358, Epsilon: 0.528
# Episode 639, Reward: -521.06, Score:  346, Epsilon: 0.528
# Episode 640, Reward: -100.45, Score:  548, Epsilon: 0.527
# Episode 641, Reward: -461.21, Score:  306, Epsilon: 0.527
# Episode 642, Reward: -315.62, Score:  362, Epsilon: 0.526
# Episode 643, Reward: -1264.31, Score:  200, Epsilon: 0.526
# Episode 644, Reward: -564.66, Score:  372, Epsilon: 0.525
# Episode 645, Reward: -439.34, Score:  334, Epsilon: 0.524
# Episode 646, Reward: -833.38, Score:  252, Epsilon: 0.524
# Episode 647, Reward: -871.25, Score:  300, Epsilon: 0.523
# Episode 648, Reward:  490.49, Score:  740, Epsilon: 0.523
# Episode 649, Reward: -923.47, Score:  250, Epsilon: 0.522
# Episode 650, Reward:  615.21, Score:  796, Epsilon: 0.522
# Checkpoint saved at episode 650, best score: 1562.00
# Episode 651, Reward: -311.42, Score:  526, Epsilon: 0.521
# Episode 652, Reward:   55.64, Score:  622, Epsilon: 0.521
# Episode 653, Reward: -255.14, Score:  418, Epsilon: 0.520
# Episode 654, Reward:  147.52, Score:  470, Epsilon: 0.520
# Episode 655, Reward: -691.49, Score:  286, Epsilon: 0.519
# Episode 656, Reward: -992.03, Score:  470, Epsilon: 0.519
# Episode 657, Reward: -550.50, Score:  552, Epsilon: 0.518
# Episode 658, Reward: -316.46, Score:  416, Epsilon: 0.518
# Episode 659, Reward: -476.33, Score:  380, Epsilon: 0.517
# Episode 660, Reward: -399.51, Score:  552, Epsilon: 0.517
# Episode 661, Reward: -911.95, Score:  278, Epsilon: 0.516
# Episode 662, Reward: -1359.85, Score:  142, Epsilon: 0.516
# Episode 663, Reward: -526.24, Score:  520, Epsilon: 0.515
# Episode 664, Reward: -1228.00, Score:  250, Epsilon: 0.515
# Episode 665, Reward: -318.52, Score:  542, Epsilon: 0.514
# Episode 666, Reward: -651.88, Score:  344, Epsilon: 0.514
# Episode 667, Reward: -254.15, Score:  488, Epsilon: 0.513
# Episode 668, Reward: -1413.99, Score:  636, Epsilon: 0.513
# Episode 669, Reward: -121.72, Score:  606, Epsilon: 0.512
# Episode 670, Reward: -898.96, Score:  330, Epsilon: 0.512
# Episode 671, Reward: -984.23, Score:  194, Epsilon: 0.511
# Episode 672, Reward: -324.32, Score:  490, Epsilon: 0.511
# Episode 673, Reward: -725.93, Score:  304, Epsilon: 0.510
# Episode 674, Reward: -772.68, Score:  304, Epsilon: 0.509
# Episode 675, Reward:  475.41, Score:  708, Epsilon: 0.509
# Episode 676, Reward:  -49.91, Score:  484, Epsilon: 0.508
# Episode 677, Reward: 1062.95, Score:  814, Epsilon: 0.508
# Episode 678, Reward: -155.04, Score:  458, Epsilon: 0.507
# Episode 679, Reward: -351.57, Score:  414, Epsilon: 0.507
# Episode 680, Reward: -303.04, Score:  474, Epsilon: 0.506
# Episode 681, Reward: -483.36, Score:  408, Epsilon: 0.506
# Episode 682, Reward:  158.49, Score:  682, Epsilon: 0.505
# Episode 683, Reward: -1406.91, Score:  274, Epsilon: 0.505
# Episode 684, Reward: -615.25, Score:  348, Epsilon: 0.504
# Episode 685, Reward:  689.26, Score:  710, Epsilon: 0.504
# Episode 686, Reward: -331.00, Score:  410, Epsilon: 0.503
# Episode 687, Reward:  -56.78, Score:  538, Epsilon: 0.503
# Episode 688, Reward: -1234.13, Score:  348, Epsilon: 0.502
# Episode 689, Reward: -318.04, Score:  406, Epsilon: 0.502
# Episode 690, Reward: -771.17, Score:  340, Epsilon: 0.501
# Episode 691, Reward: -110.47, Score:  528, Epsilon: 0.501
# Episode 692, Reward:  246.35, Score:  688, Epsilon: 0.500
# Episode 693, Reward: 1088.81, Score: 1088, Epsilon: 0.500
# Episode 694, Reward: -339.20, Score:  382, Epsilon: 0.499
# Episode 695, Reward: -779.63, Score:  370, Epsilon: 0.499
# Episode 696, Reward:  -38.46, Score:  500, Epsilon: 0.498
# Episode 697, Reward: -192.17, Score:  458, Epsilon: 0.498
# Episode 698, Reward: -570.14, Score:  366, Epsilon: 0.497
# Episode 699, Reward: -703.69, Score:  340, Epsilon: 0.497
# Episode 700, Reward:    5.49, Score:  468, Epsilon: 0.496
# Checkpoint saved at episode 700, best score: 1562.00
# Episode 701, Reward: 1057.48, Score: 1064, Epsilon: 0.496
# Episode 702, Reward:  334.36, Score:  636, Epsilon: 0.495
# Episode 703, Reward:   49.36, Score:  604, Epsilon: 0.495
# Episode 704, Reward: -1328.32, Score:  190, Epsilon: 0.494
# Episode 705, Reward:   -7.05, Score:  580, Epsilon: 0.494
# Episode 706, Reward: -273.84, Score:  416, Epsilon: 0.493
# Episode 707, Reward: -940.89, Score:  314, Epsilon: 0.493
# Episode 708, Reward: -561.22, Score:  322, Epsilon: 0.492
# Episode 709, Reward: -895.03, Score:  250, Epsilon: 0.492
# Episode 710, Reward: -238.12, Score:  624, Epsilon: 0.491
# Episode 711, Reward: -798.46, Score:  294, Epsilon: 0.491
# Episode 712, Reward: -160.15, Score:  382, Epsilon: 0.490
# Episode 713, Reward: -1123.15, Score:  220, Epsilon: 0.490
# Episode 714, Reward: -1319.31, Score:  250, Epsilon: 0.490
# Episode 715, Reward: -1122.37, Score:  168, Epsilon: 0.489
# Episode 716, Reward:  730.48, Score:  914, Epsilon: 0.489
# Episode 717, Reward: -411.33, Score:  432, Epsilon: 0.488
# Episode 718, Reward:  880.91, Score:  982, Epsilon: 0.488
# Episode 719, Reward: -130.12, Score:  470, Epsilon: 0.487
# Episode 720, Reward: -492.58, Score:  322, Epsilon: 0.487
# Episode 721, Reward:  353.54, Score:  674, Epsilon: 0.486
# Episode 722, Reward: -481.13, Score:  332, Epsilon: 0.486
# Episode 723, Reward:  -85.77, Score:  468, Epsilon: 0.485
# Episode 724, Reward:   70.39, Score:  514, Epsilon: 0.485
# Episode 725, Reward: -1027.33, Score:  120, Epsilon: 0.484
# Episode 726, Reward: -1148.07, Score:  274, Epsilon: 0.484
# Episode 727, Reward: -1002.04, Score:  148, Epsilon: 0.483
# Episode 728, Reward: -978.54, Score:  288, Epsilon: 0.483
# Episode 729, Reward: -1001.28, Score:  506, Epsilon: 0.482
# Episode 730, Reward:  428.16, Score:  850, Epsilon: 0.482
# Episode 731, Reward:  -86.15, Score:  428, Epsilon: 0.481
# Episode 732, Reward: -503.82, Score:  322, Epsilon: 0.481
# Episode 733, Reward: -120.72, Score:  490, Epsilon: 0.480
# Episode 734, Reward: -1126.50, Score:  210, Epsilon: 0.480
# Episode 735, Reward: -618.90, Score:  476, Epsilon: 0.479
# Episode 736, Reward: -820.69, Score:  246, Epsilon: 0.479
# Episode 737, Reward:  -21.45, Score:  516, Epsilon: 0.478
# Episode 738, Reward: -474.64, Score:  408, Epsilon: 0.478
# Episode 739, Reward: -418.92, Score:  322, Epsilon: 0.477
# Episode 740, Reward: -404.89, Score:  378, Epsilon: 0.477
# Episode 741, Reward: -822.09, Score:  280, Epsilon: 0.476
# Episode 742, Reward: -1416.68, Score:  328, Epsilon: 0.476
# Episode 743, Reward: -917.86, Score:  210, Epsilon: 0.476
# Episode 744, Reward: -886.71, Score:  254, Epsilon: 0.475
# Episode 745, Reward: -643.31, Score:  344, Epsilon: 0.475
# Episode 746, Reward:  -90.38, Score:  502, Epsilon: 0.474
# Episode 747, Reward: -127.29, Score:  580, Epsilon: 0.474
# Episode 748, Reward: -1025.97, Score:  174, Epsilon: 0.473
# Episode 749, Reward: -311.81, Score:  568, Epsilon: 0.473
# Episode 750, Reward: -725.61, Score:  496, Epsilon: 0.472
# Checkpoint saved at episode 750, best score: 1562.00
# Episode 751, Reward: -1203.72, Score:  252, Epsilon: 0.472
# Episode 752, Reward: -969.36, Score:  310, Epsilon: 0.471
# Episode 753, Reward:  133.40, Score:  676, Epsilon: 0.471
# Episode 754, Reward: -755.56, Score:  292, Epsilon: 0.470
# Episode 755, Reward: -1009.36, Score:  572, Epsilon: 0.470
# Episode 756, Reward: -188.28, Score:  462, Epsilon: 0.469
# Episode 757, Reward: -412.58, Score:  392, Epsilon: 0.469
# Episode 758, Reward: -722.58, Score:  562, Epsilon: 0.468
# Episode 759, Reward: -462.10, Score:  424, Epsilon: 0.468
# Episode 760, Reward: -741.71, Score:  258, Epsilon: 0.467
# Episode 761, Reward: -199.95, Score:  656, Epsilon: 0.467
# Episode 762, Reward: -612.78, Score:  340, Epsilon: 0.467
# Episode 763, Reward: -382.05, Score:  416, Epsilon: 0.466
# Episode 764, Reward: -758.51, Score:  262, Epsilon: 0.466
# Episode 765, Reward: -864.81, Score:  246, Epsilon: 0.465
# Episode 766, Reward:  253.40, Score:  630, Epsilon: 0.465
# Episode 767, Reward: -750.50, Score:  270, Epsilon: 0.464
# Episode 768, Reward: -1323.82, Score:  138, Epsilon: 0.464
# Episode 769, Reward: -597.41, Score:  456, Epsilon: 0.463
# Episode 770, Reward: -641.00, Score:  306, Epsilon: 0.463
# Episode 771, Reward: -1031.64, Score:  268, Epsilon: 0.462
# Episode 772, Reward: -548.12, Score:  288, Epsilon: 0.462
# Episode 773, Reward: -1362.06, Score:  166, Epsilon: 0.461
# Episode 774, Reward: -369.17, Score:  588, Epsilon: 0.461
# Episode 775, Reward: -873.08, Score:  236, Epsilon: 0.461
# Episode 776, Reward: -531.11, Score:  500, Epsilon: 0.460
# Episode 777, Reward: -536.57, Score:  440, Epsilon: 0.460
# Episode 778, Reward: -352.83, Score:  570, Epsilon: 0.459
# Episode 779, Reward: -422.31, Score:  348, Epsilon: 0.459
# Episode 780, Reward: -987.62, Score:  274, Epsilon: 0.458
# Episode 781, Reward:  -33.76, Score:  606, Epsilon: 0.458
# Episode 782, Reward:   55.36, Score:  468, Epsilon: 0.457
# Episode 783, Reward: -1175.93, Score:  126, Epsilon: 0.457
# Episode 784, Reward: -138.83, Score:  540, Epsilon: 0.456
# Episode 785, Reward: -256.69, Score:  394, Epsilon: 0.456
# Episode 786, Reward:  224.19, Score:  628, Epsilon: 0.455
# Episode 787, Reward: -406.15, Score:  354, Epsilon: 0.455
# Episode 788, Reward: -455.87, Score:  538, Epsilon: 0.455
# Episode 789, Reward:   31.30, Score:  484, Epsilon: 0.454
# Episode 790, Reward: -993.55, Score:  316, Epsilon: 0.454
# Episode 791, Reward: -468.69, Score:  534, Epsilon: 0.453
# Episode 792, Reward: -313.27, Score:  510, Epsilon: 0.453
# Episode 793, Reward:  240.04, Score:  656, Epsilon: 0.452
# Episode 794, Reward: -632.99, Score:  400, Epsilon: 0.452
# Episode 795, Reward:  724.59, Score:  652, Epsilon: 0.451
# Episode 796, Reward: -529.98, Score:  432, Epsilon: 0.451
# Episode 797, Reward:    3.02, Score:  500, Epsilon: 0.450
# Episode 798, Reward: -742.94, Score:  332, Epsilon: 0.450
# Episode 799, Reward: -467.18, Score:  358, Epsilon: 0.450
# ...
# Episode 3736, Reward: 3790.05, Score: 1348, Epsilon: 0.024
# Episode 3737, Reward: 12176.28, Score: 3342, Epsilon: 0.024
# Episode 3738, Reward: 7380.74, Score: 2352, Epsilon: 0.024
# Episode 3739, Reward: 3974.12, Score: 1596, Epsilon: 0.024
# Episode 3740, Reward: 7814.35, Score: 2246, Epsilon: 0.024
# Episode 3741, Reward: 11105.18, Score: 3280, Epsilon: 0.024
# Episode 3742, Reward: 5527.10, Score: 1818, Epsilon: 0.024
# Episode 3743, Reward: 5853.09, Score: 2054, Epsilon: 0.024
# Episode 3744, Reward: 2742.27, Score: 1276, Epsilon: 0.024
# Episode 3745, Reward: 9344.67, Score: 2782, Epsilon: 0.024
# Episode 3746, Reward: 7804.60, Score: 2390, Epsilon: 0.024
# Episode 3747, Reward: -434.75, Score:  432, Epsilon: 0.024
# Episode 3748, Reward: 3032.48, Score: 1380, Epsilon: 0.024
# Episode 3749, Reward: 9405.25, Score: 2874, Epsilon: 0.023
# Episode 3750, Reward: 2249.57, Score: 1016, Epsilon: 0.023
# Checkpoint saved at episode 3750, best score: 7020.00
# Episode 3751, Reward: 6190.98, Score: 1968, Epsilon: 0.023
# Episode 3752, Reward:  533.33, Score:  570, Epsilon: 0.023
# Episode 3753, Reward: 4606.87, Score: 1522, Epsilon: 0.023
# Episode 3754, Reward: 1997.53, Score: 1234, Epsilon: 0.023
# Episode 3755, Reward: 9213.01, Score: 2910, Epsilon: 0.023
# Episode 3756, Reward: 13763.04, Score: 3792, Epsilon: 0.023
# Episode 3757, Reward: 4132.48, Score: 1442, Epsilon: 0.023
# Episode 3758, Reward: 10352.78, Score: 2958, Epsilon: 0.023
# Episode 3759, Reward: 5046.21, Score: 1814, Epsilon: 0.023
# Episode 3760, Reward: 5566.78, Score: 2008, Epsilon: 0.023
# Episode 3761, Reward: 4943.98, Score: 1952, Epsilon: 0.023
# Episode 3762, Reward: 7976.86, Score: 2702, Epsilon: 0.023
# Episode 3763, Reward: 1433.29, Score:  962, Epsilon: 0.023
# Episode 3764, Reward: 4364.61, Score: 1560, Epsilon: 0.023
# Episode 3765, Reward: 2768.53, Score: 1282, Epsilon: 0.023
# Episode 3766, Reward: 4046.79, Score: 1420, Epsilon: 0.023
# Episode 3767, Reward: 1453.94, Score:  896, Epsilon: 0.023
# Episode 3768, Reward: 7520.31, Score: 2430, Epsilon: 0.023
# Episode 3769, Reward: 4017.62, Score: 1628, Epsilon: 0.023
# Episode 3770, Reward: 14604.61, Score: 3994, Epsilon: 0.023
# Episode 3771, Reward: 2508.12, Score: 1050, Epsilon: 0.023
# Episode 3772, Reward: 2711.90, Score: 1212, Epsilon: 0.023
# Episode 3773, Reward: 11566.23, Score: 3500, Epsilon: 0.023
# Episode 3774, Reward: 8947.32, Score: 2808, Epsilon: 0.023
# Episode 3775, Reward:  788.25, Score:  744, Epsilon: 0.023
# Episode 3776, Reward: 1582.22, Score: 1054, Epsilon: 0.023
# Episode 3777, Reward: 2283.42, Score: 1076, Epsilon: 0.023
# Episode 3778, Reward: 3785.25, Score: 1404, Epsilon: 0.023
# Episode 3779, Reward: 2285.34, Score: 1066, Epsilon: 0.023
# Episode 3780, Reward: 4569.91, Score: 1510, Epsilon: 0.023
# Episode 3781, Reward: 7029.90, Score: 2280, Epsilon: 0.023
# Episode 3782, Reward: 5954.17, Score: 1808, Epsilon: 0.023
# Episode 3783, Reward: 4367.24, Score: 1642, Epsilon: 0.023
# Episode 3784, Reward: 1206.75, Score:  974, Epsilon: 0.023
# Episode 3785, Reward: 2263.48, Score: 1040, Epsilon: 0.023
# Episode 3786, Reward: 2796.18, Score: 1334, Epsilon: 0.023
# Episode 3787, Reward: 2537.91, Score: 1280, Epsilon: 0.023
# Episode 3788, Reward: 10957.63, Score: 3220, Epsilon: 0.023
# Episode 3789, Reward: 10363.50, Score: 3072, Epsilon: 0.023
# Episode 3790, Reward: 1768.89, Score: 1108, Epsilon: 0.023
# Episode 3791, Reward: 4462.92, Score: 1706, Epsilon: 0.023
# Episode 3792, Reward: 7695.02, Score: 2374, Epsilon: 0.023
# Episode 3793, Reward: 12951.39, Score: 3782, Epsilon: 0.022
# Episode 3794, Reward: 5680.12, Score: 2102, Epsilon: 0.022
# Episode 3795, Reward: 1845.11, Score:  946, Epsilon: 0.022
# Episode 3796, Reward: 11010.90, Score: 3182, Epsilon: 0.022
# Episode 3797, Reward: 5295.88, Score: 1766, Epsilon: 0.022
# Episode 3798, Reward: 7149.00, Score: 2336, Epsilon: 0.022
# Episode 3799, Reward: 6399.84, Score: 1902, Epsilon: 0.022
# Episode 3800, Reward: 26593.21, Score: 5836, Epsilon: 0.022
# Checkpoint saved at episode 3800, best score: 7020.00
# Episode 3801, Reward: 2319.79, Score: 1322, Epsilon: 0.022
# Episode 3802, Reward: 7595.88, Score: 2092, Epsilon: 0.022
# Episode 3803, Reward: -119.59, Score:  532, Epsilon: 0.022
# Episode 3804, Reward: 11037.09, Score: 2986, Epsilon: 0.022
# Episode 3805, Reward: 2516.99, Score: 1174, Epsilon: 0.022
# Episode 3806, Reward: 3387.47, Score: 1440, Epsilon: 0.022
# Episode 3807, Reward: 5962.71, Score: 2042, Epsilon: 0.022
# Episode 3808, Reward: 4073.35, Score: 1530, Epsilon: 0.022
# Episode 3809, Reward: 1482.21, Score:  870, Epsilon: 0.022
# Episode 3810, Reward: 6835.16, Score: 2256, Epsilon: 0.022
# Episode 3811, Reward: 2916.39, Score: 1258, Epsilon: 0.022
# Episode 3812, Reward: 2039.58, Score: 1008, Epsilon: 0.022
# Episode 3813, Reward: 6311.51, Score: 1944, Epsilon: 0.022
# Episode 3814, Reward: 12896.96, Score: 3692, Epsilon: 0.022
# Episode 3815, Reward: 2302.20, Score: 1148, Epsilon: 0.022
# Episode 3816, Reward: 2665.46, Score: 1274, Epsilon: 0.022
# Episode 3817, Reward: 5638.08, Score: 1930, Epsilon: 0.022
# Episode 3818, Reward: 4298.91, Score: 1734, Epsilon: 0.022
# Episode 3819, Reward: 2761.82, Score: 1010, Epsilon: 0.022
# Episode 3820, Reward: 4355.33, Score: 1440, Epsilon: 0.022
# Episode 3821, Reward: 7014.42, Score: 2022, Epsilon: 0.022
# Episode 3822, Reward: 3199.37, Score: 1326, Epsilon: 0.022
# Episode 3823, Reward: 8407.62, Score: 2524, Epsilon: 0.022
# Episode 3824, Reward: 1352.07, Score:  872, Epsilon: 0.022
# Episode 3825, Reward: 3362.20, Score: 1384, Epsilon: 0.022
# Episode 3826, Reward: 4367.89, Score: 1486, Epsilon: 0.022
# Episode 3827, Reward: 2541.31, Score: 1280, Epsilon: 0.022
# Episode 3828, Reward: 10745.78, Score: 2978, Epsilon: 0.022
# Episode 3829, Reward: 6615.78, Score: 2112, Epsilon: 0.022
# Episode 3830, Reward: 4931.41, Score: 1508, Epsilon: 0.022
# Episode 3831, Reward: 3827.92, Score: 1414, Epsilon: 0.022
# Episode 3832, Reward:  548.74, Score:  636, Epsilon: 0.022
# Episode 3833, Reward: 1438.87, Score: 1072, Epsilon: 0.022
# Episode 3834, Reward: 4150.80, Score: 1476, Epsilon: 0.022
# Episode 3835, Reward: 9070.59, Score: 2892, Epsilon: 0.022
# Episode 3836, Reward: 18368.66, Score: 4810, Epsilon: 0.022
# Episode 3837, Reward: 8481.88, Score: 2810, Epsilon: 0.022
# Episode 3838, Reward: 4005.10, Score: 1744, Epsilon: 0.021
# Episode 3839, Reward: 4464.62, Score: 1536, Epsilon: 0.021
# Episode 3840, Reward: 4261.00, Score: 1716, Epsilon: 0.021
# Episode 3841, Reward: 7173.09, Score: 2202, Epsilon: 0.021
# Episode 3842, Reward: 12159.62, Score: 3592, Epsilon: 0.021
# Episode 3843, Reward: 2356.66, Score: 1058, Epsilon: 0.021
# Episode 3844, Reward: 3676.51, Score: 1412, Epsilon: 0.021
# Episode 3845, Reward: 5585.53, Score: 2226, Epsilon: 0.021
# Episode 3846, Reward: 6151.91, Score: 2040, Epsilon: 0.021
# Episode 3847, Reward: 4989.88, Score: 1664, Epsilon: 0.021
# Episode 3848, Reward: 2964.59, Score: 1394, Epsilon: 0.021
# Episode 3849, Reward: 4696.95, Score: 1556, Epsilon: 0.021
# Episode 3850, Reward: 11137.93, Score: 3088, Epsilon: 0.021
# Checkpoint saved at episode 3850, best score: 7020.00
# Episode 3851, Reward: 6483.06, Score: 2058, Epsilon: 0.021
# Episode 3852, Reward: 8908.68, Score: 2668, Epsilon: 0.021
# Episode 3853, Reward: 4755.05, Score: 1796, Epsilon: 0.021
# Episode 3854, Reward: 7632.98, Score: 2396, Epsilon: 0.021
# Episode 3855, Reward: 5345.50, Score: 1834, Epsilon: 0.021
# Episode 3856, Reward: 7960.34, Score: 2434, Epsilon: 0.021
# Episode 3857, Reward: 2123.12, Score: 1002, Epsilon: 0.021
# Episode 3858, Reward:  535.22, Score:  726, Epsilon: 0.021
# Episode 3859, Reward: 10745.30, Score: 3066, Epsilon: 0.021
# Episode 3860, Reward: 8137.60, Score: 2572, Epsilon: 0.021
# Episode 3861, Reward: 4263.61, Score: 1442, Epsilon: 0.021
# Episode 3862, Reward:  425.95, Score:  644, Epsilon: 0.021
# Episode 3863, Reward: 4218.26, Score: 1684, Epsilon: 0.021
# Episode 3864, Reward: 6353.23, Score: 2096, Epsilon: 0.021
# Episode 3865, Reward: 11189.03, Score: 3380, Epsilon: 0.021
# Episode 3866, Reward: 2000.46, Score: 1186, Epsilon: 0.021
# Episode 3867, Reward: 7610.58, Score: 2332, Epsilon: 0.021
# Episode 3868, Reward: 2083.50, Score:  864, Epsilon: 0.021
# Episode 3869, Reward: 1272.36, Score:  928, Epsilon: 0.021
# Episode 3870, Reward: 1359.46, Score:  792, Epsilon: 0.021
# Episode 3871, Reward: 2143.96, Score: 1032, Epsilon: 0.021
# Episode 3872, Reward: 3320.35, Score: 1286, Epsilon: 0.021
# Episode 3873, Reward: 6623.36, Score: 2242, Epsilon: 0.021
# Episode 3874, Reward: 2266.35, Score: 1192, Epsilon: 0.021
# Episode 3875, Reward: 5647.71, Score: 1902, Epsilon: 0.021
# Episode 3876, Reward: 5523.81, Score: 1800, Epsilon: 0.021
# Episode 3877, Reward: 10006.32, Score: 3066, Epsilon: 0.021
# Episode 3878, Reward: 5945.38, Score: 2062, Epsilon: 0.021
# Episode 3879, Reward: 2993.51, Score: 1284, Epsilon: 0.021
# Episode 3880, Reward: 6380.10, Score: 2064, Epsilon: 0.021
# Episode 3881, Reward: 16318.60, Score: 4286, Epsilon: 0.021
# Episode 3882, Reward: 3669.83, Score: 1492, Epsilon: 0.021
# Episode 3883, Reward: 2798.83, Score: 1356, Epsilon: 0.021
# Episode 3884, Reward: 3197.17, Score: 1374, Epsilon: 0.021
# Episode 3885, Reward: 9640.64, Score: 3096, Epsilon: 0.021
# Episode 3886, Reward: 3010.21, Score: 1152, Epsilon: 0.020
# Episode 3887, Reward: 7318.96, Score: 2216, Epsilon: 0.020
# Episode 3888, Reward: 4208.75, Score: 1918, Epsilon: 0.020
# Episode 3889, Reward: 2142.72, Score: 1054, Epsilon: 0.020
# Episode 3890, Reward:  565.33, Score:  578, Epsilon: 0.020
# Episode 3891, Reward: 9869.04, Score: 3192, Epsilon: 0.020
# Episode 3892, Reward: 4653.11, Score: 1572, Epsilon: 0.020
# Episode 3893, Reward: 9718.35, Score: 2834, Epsilon: 0.020
# Episode 3894, Reward:  -53.80, Score:  480, Epsilon: 0.020
# Episode 3895, Reward: 8422.58, Score: 2618, Epsilon: 0.020
# Episode 3896, Reward: 7666.62, Score: 2442, Epsilon: 0.020
# Episode 3897, Reward: 9556.89, Score: 2666, Epsilon: 0.020
# Episode 3898, Reward:  -39.65, Score:  452, Epsilon: 0.020
# Episode 3899, Reward: 4580.74, Score: 1748, Epsilon: 0.020
# Episode 3900, Reward:  478.67, Score:  602, Epsilon: 0.020
# Checkpoint saved at episode 3900, best score: 7020.00
# Episode 3901, Reward:  624.81, Score:  622, Epsilon: 0.020
# Episode 3902, Reward: 13133.70, Score: 3362, Epsilon: 0.020
# Episode 3903, Reward: 7732.89, Score: 2596, Epsilon: 0.020
# Episode 3904, Reward: 8141.92, Score: 2494, Epsilon: 0.020
# Episode 3905, Reward: 5562.50, Score: 2112, Epsilon: 0.020
# Episode 3906, Reward: 10814.85, Score: 2918, Epsilon: 0.020
# Episode 3907, Reward: 7501.11, Score: 2244, Epsilon: 0.020
# Episode 3908, Reward: 8928.05, Score: 2498, Epsilon: 0.020
# Episode 3909, Reward: 11160.19, Score: 3002, Epsilon: 0.020
# Episode 3910, Reward: 2598.60, Score: 1168, Epsilon: 0.020
# Episode 3911, Reward: 7357.08, Score: 2204, Epsilon: 0.020
# Episode 3912, Reward: 4967.10, Score: 1654, Epsilon: 0.020
# Episode 3913, Reward: 3660.35, Score: 1600, Epsilon: 0.020
# Episode 3914, Reward: 7156.25, Score: 2180, Epsilon: 0.020
# Episode 3915, Reward: 5944.93, Score: 1898, Epsilon: 0.020
# Episode 3916, Reward: 3075.87, Score: 1268, Epsilon: 0.020
# Episode 3917, Reward: 4128.12, Score: 1482, Epsilon: 0.020
# Episode 3918, Reward: 4550.70, Score: 1622, Epsilon: 0.020
# Episode 3919, Reward: 4453.59, Score: 1560, Epsilon: 0.020
# Episode 3920, Reward: 5253.44, Score: 1766, Epsilon: 0.020
# Episode 3921, Reward: 11849.21, Score: 3110, Epsilon: 0.020
# Episode 3922, Reward: 7332.12, Score: 2358, Epsilon: 0.020
# Episode 3923, Reward: 14224.54, Score: 3370, Epsilon: 0.020
# Episode 3924, Reward: 1366.51, Score:  916, Epsilon: 0.020
# Episode 3925, Reward: 4723.80, Score: 1686, Epsilon: 0.020
# Episode 3926, Reward: 5822.22, Score: 1820, Epsilon: 0.020
# Episode 3927, Reward: 6932.28, Score: 2270, Epsilon: 0.020
# Episode 3928, Reward: 7543.58, Score: 2476, Epsilon: 0.020
# Episode 3929, Reward: 3406.71, Score: 1366, Epsilon: 0.020
# Episode 3930, Reward: 14457.04, Score: 3522, Epsilon: 0.020
# Episode 3931, Reward: 19098.66, Score: 4638, Epsilon: 0.020
# Episode 3932, Reward: 6631.13, Score: 2216, Epsilon: 0.020
# Episode 3933, Reward: 5077.13, Score: 1956, Epsilon: 0.020
# Episode 3934, Reward: 6306.61, Score: 1938, Epsilon: 0.020
# Episode 3935, Reward: 1183.52, Score:  860, Epsilon: 0.020
# Episode 3936, Reward: 3658.32, Score: 1550, Epsilon: 0.019
# Episode 3937, Reward: 4753.79, Score: 1604, Epsilon: 0.019
# Episode 3938, Reward: 3274.12, Score: 1434, Epsilon: 0.019
# Episode 3939, Reward: 4664.18, Score: 1756, Epsilon: 0.019
# Episode 3940, Reward: 3935.89, Score: 1534, Epsilon: 0.019
# Episode 3941, Reward: 7950.64, Score: 2540, Epsilon: 0.019
# Episode 3942, Reward: 9550.66, Score: 2622, Epsilon: 0.019
# Episode 3943, Reward: 1017.35, Score:  868, Epsilon: 0.019
# Episode 3944, Reward: 2863.55, Score: 1330, Epsilon: 0.019
# Episode 3945, Reward: 3540.81, Score: 1388, Epsilon: 0.019
# Episode 3946, Reward: 9643.93, Score: 2944, Epsilon: 0.019
# Episode 3947, Reward: 7356.63, Score: 2562, Epsilon: 0.019
# Episode 3948, Reward: 1686.82, Score:  978, Epsilon: 0.019
# Episode 3949, Reward: 10056.97, Score: 2926, Epsilon: 0.019
# Episode 3950, Reward: 10022.69, Score: 3332, Epsilon: 0.019
# Checkpoint saved at episode 3950, best score: 7020.00
# Episode 3951, Reward:  462.34, Score:  468, Epsilon: 0.019
# Episode 3952, Reward: 4217.80, Score: 1674, Epsilon: 0.019
# Episode 3953, Reward: 5803.79, Score: 2014, Epsilon: 0.019
# Episode 3954, Reward: 11228.74, Score: 3388, Epsilon: 0.019
# Episode 3955, Reward: 16319.74, Score: 4280, Epsilon: 0.019
# Episode 3956, Reward: 5336.61, Score: 1768, Epsilon: 0.019
# Episode 3957, Reward: 4102.08, Score: 1726, Epsilon: 0.019
# Episode 3958, Reward: 1356.96, Score:  836, Epsilon: 0.019
# Episode 3959, Reward: 4424.29, Score: 1814, Epsilon: 0.019
# Episode 3960, Reward: 3537.92, Score: 1566, Epsilon: 0.019
# Episode 3961, Reward: 5937.95, Score: 2114, Epsilon: 0.019
# Episode 3962, Reward: 4034.12, Score: 1532, Epsilon: 0.019
# Episode 3963, Reward: 9450.76, Score: 2898, Epsilon: 0.019
# Episode 3964, Reward: 4020.97, Score: 1590, Epsilon: 0.019
# Episode 3965, Reward: 6282.66, Score: 1928, Epsilon: 0.019
# Episode 3966, Reward: 4217.67, Score: 1630, Epsilon: 0.019
# Episode 3967, Reward: 4999.58, Score: 1610, Epsilon: 0.019
# Episode 3968, Reward: 2753.71, Score: 1234, Epsilon: 0.019
# Episode 3969, Reward: 4510.15, Score: 1746, Epsilon: 0.019
# Episode 3970, Reward: 5015.31, Score: 1778, Epsilon: 0.019
# Episode 3971, Reward: 9514.33, Score: 3084, Epsilon: 0.019
# Episode 3972, Reward: 6917.82, Score: 2086, Epsilon: 0.019
# Episode 3973, Reward: 2213.64, Score: 1290, Epsilon: 0.019
# Episode 3974, Reward: 7648.96, Score: 2440, Epsilon: 0.019
# Episode 3975, Reward: 8624.42, Score: 2664, Epsilon: 0.019
# Episode 3976, Reward: 11009.64, Score: 2920, Epsilon: 0.019
# Episode 3977, Reward: 12031.09, Score: 3448, Epsilon: 0.019
# Episode 3978, Reward: 3218.20, Score: 1534, Epsilon: 0.019
# Episode 3979, Reward: 12680.89, Score: 3440, Epsilon: 0.019
# Episode 3980, Reward: 12146.99, Score: 3460, Epsilon: 0.019
# Episode 3981, Reward: 11123.70, Score: 3172, Epsilon: 0.019
# Episode 3982, Reward: 3965.23, Score: 1656, Epsilon: 0.019
# Episode 3983, Reward: 5197.71, Score: 1996, Epsilon: 0.019
# Episode 3984, Reward: 6883.90, Score: 2026, Epsilon: 0.019
# Episode 3985, Reward: 30357.15, Score: 6130, Epsilon: 0.019
# Episode 3986, Reward: 1250.43, Score:  836, Epsilon: 0.019
# Episode 3987, Reward: 3433.23, Score: 1544, Epsilon: 0.019
# Episode 3988, Reward: 3469.99, Score: 1682, Epsilon: 0.018
# Episode 3989, Reward: 8017.47, Score: 2424, Epsilon: 0.018
# Episode 3990, Reward: 5424.80, Score: 1844, Epsilon: 0.018
# Episode 3991, Reward: 7419.06, Score: 2346, Epsilon: 0.018
# Episode 3992, Reward: 3479.75, Score: 1238, Epsilon: 0.018
# Episode 3993, Reward: 12635.00, Score: 3576, Epsilon: 0.018
# Episode 3994, Reward: 4360.91, Score: 1618, Epsilon: 0.018
# Episode 3995, Reward: 1096.06, Score:  802, Epsilon: 0.018
# Episode 3996, Reward: 22745.40, Score: 5262, Epsilon: 0.018
# Episode 3997, Reward: 7821.45, Score: 2628, Epsilon: 0.018
# Episode 3998, Reward: 2625.64, Score: 1230, Epsilon: 0.018
# Episode 3999, Reward: 9591.03, Score: 2850, Epsilon: 0.018
# Episode 4000, Reward: 6725.71, Score: 2152, Epsilon: 0.018
# Checkpoint saved at episode 4000, best score: 7020.00

# %%
from scipy.ndimage import gaussian_filter1d

reward_smooth = gaussian_filter1d(reward_history, sigma=50)
score_smooth = gaussian_filter1d(score_history, sigma=50)

# 畫圖
# plt.figure(figsize=(10, 5))
plt.plot(reward_history, label='Total Reward', alpha=0.8)
plt.plot(score_history, label='Score', alpha=0.8)
plt.plot(reward_smooth, label='Smoothed Total Reward', linewidth=2)
plt.plot(score_smooth, label='Smoothed Score', linewidth=2)

plt.legend(loc='upper left')
plt.xlabel("Episode")
plt.ylabel("Value")
plt.title("Training Reward Over Episodes")
plt.grid(True)
plt.tight_layout()
# plt.savefig("dqn_training_curve.png")
